# %% [markdown]
# # Projeto e Análise de Algoritmos
# ## **Author:** Natanael Bezerra de Oliveira

# %% [markdown]
# ## Notação
#
# 1. **Notação  $ ( O ) $   (Big O):** Descreve um limite superior no crescimento de uma função. Se $ f(n) = O(g(n)) $, isso significa que existe uma constante  $ C >= 0 $ tal que $ f(n) \leq C \cdot g(n) $ para todos os $ n \geq n_0 $ suficientemente grandes.
#
# 2. **Notação \( $\Theta$ \) (Big Theta):** Descreve uma função que tem tanto um limite superior quanto um limite inferior assintoticamente apertados. Se $  f(n) = \Theta(g(n))  $, isso significa que existem constantes $ C_1, C_2 > 0 $ tais que $ C_1 \cdot g(n) \leq f(n) \leq C_2 \cdot g(n) $ para todos os $ n \geq n_0 $ suficientemente grandes.
#
# 3. **Notação $( \Omega )$ (Big Omega):** Descreve um limite inferior no crescimento de uma função. Se $ f(n) = \Omega(g(n)) $, isso significa que existe uma constante $ C > 0 $ tal que $ f(n) \geq C \cdot g(n) $ para todos os $ n \geq n_0 $ suficientemente grandes.
#
# 4. **Notação $( o )$ (Little o):** Descreve um limite superior estrito. Se $ f(n) = o(g(n)) $, isso significa que $\lim_{n \to \infty} \frac{f(n)}{g(n)} = 0 $. Em outras palavras, $ f(n) $ cresce estritamente mais devagar do que $ g(n) $.
#
# 5. **Notação $ ( \omega ) $ (Little Omega):** Descreve um limite inferior estrito. Se $  f(n) = \omega(g(n)) $, isso significa que $ \lim_{n \to \infty} \frac{f(n)}{g(n)} = \infty $. Em outras palavras, \( f(n) \) cresce estritamente mais rápido do que $ g(n) $.

# %% [markdown]
# ## Exercícios da aula 02
#
# • Verifique se as afirmativas são corretas:

# %% [markdown]
# ### a) $$n^{2n} = O(2^n)$$
#
# * Primeiro calculando o limite:
# $$\lim _{n\to \infty }\left(\frac{2^{2n}}{2^n}\right)$$
#
# Simplificando a expressão, tem-se:
# $$\lim _{n\to \infty }\left(\frac{2^{n}*2^{n}}{2^n}\right)$$
# $$\lim _{n\to \infty }\left(2^{n}\right)$$
#
#
# Isso é fácil de perceber que o limite é $ \infty $, logo, como não é uma constante, então não é $ O(2^n) $.

# %% [markdown]
# ### b) $$2^{n+1} = O(2^n)$$
# * Primeiro calculando o limite:
# $$\lim _{n\to \infty }\left(\frac{2^{n+1}}{2^n}\right)$$
#
# Simplificando a expressão:
# $$\lim _{n\to \infty }\left(\frac{2^{n} * 2}{2^n}\right) = 2$$
#
# Como o limite é uma constante, podemos afirmar que $2^{n+1}$ é $O(2^n)$.

# %% [markdown]
# ### c) $$O(n^2) + O(n^2) = O(n^2)$$
#
# * Primeiro calculando o limite:
# $$\lim _{n\to \infty }\left(\frac{2n^2}{n^2}\right) = 2$$
#
#
# Como o limite é uma constante, podemos afirmar que $O(n^2) + O(n^2) $ é $O(n^2)$.

# %% [markdown]
# ### d) $$O(n) * O(n) = O(n)$$
#
# Analisando, é possível perceber que $n*n = n^2$.
# Logo, calculando o limite, tem-se:
# $$\lim _{n\to \infty }\left(\frac{n^2}{n}\right) = \lim _{n\to \infty }\left(n\right)$$
#
# Isso é fácil de perceber que o limite é $ \infty $, logo, como não é uma constante, então não é $ O(n) $.

# %% [markdown]
# ## Teorema Mestre
# O Teorema Mestre é uma ferramenta essencial na análise de algoritmos, particularmente para algoritmos de divisão e conquista. Ele fornece uma maneira rápida e fácil de determinar a complexidade de tempo de uma equação de recorrência com uma forma específica.
#
# ### Forma da Recorrência
# O Teorema Mestre aplica-se a recorrências da seguinte forma:
#
# $ T(n) = a \cdot T\left(\frac{n}{b}\right) + f(n) $
#
# onde:
# - $ a $ é o número de subproblemas na recursão.
# - $ b > 1 $ é o fator pelo qual o tamanho do problema é dividido.
# - $ f(n) $ é o custo do trabalho feito fora das chamadas recursivas (como a combinação de subproblemas).
#
# ### Três Casos
# O teorema divide-se em três casos, que determinam a complexidade da recorrência:
#
# 1. **Caso 1:** Se $ f(n) = O(n^{\log_b{a} - \epsilon}) $ para algum $ \epsilon > 0 $, então a complexidade é $ \Theta(n^{\log_b{a}}) $.
# 2. **Caso 2:** Se $ f(n) = \Theta(n^{\log_b{a}}) $, então a complexidade é $ \Theta(n^{\log_b{a}} \log n) $.
# 3. **Caso 3:** Se $ f(n) = \Omega(n^{\log_b{a} + \epsilon}) $ para algum $ \epsilon > 0 $, e se $ a f\left(\frac{n}{b}\right) \leq kf(n) $ para algum $ k < 1 $ e $ n \geq n_0 $ suficientemente grande, então a complexidade é $ \Theta(f(n)) $.
#
# ### Limitações
# O Teorema Mestre não se aplica a todas as recorrências. Deve ser usado apenas quando a recorrência se encaixa na forma acima e satisfaz um dos três casos.
#
# ### Utilização
# O Teorema Mestre é comumente usado para analisar algoritmos de divisão e conquista, como o algoritmo de ordenação merge sort e o algoritmo de busca binária, fornecendo uma maneira eficiente de determinar a complexidade de tempo sem resolver a recorrência manualmente.

# %% [markdown]
# ## Questões de tempo de execução
#
#
# 1. Um estudante faz experimento com uma coleção de 10 mil documentos e testa seu algoritmo de custo $ \Theta(\log n) $, obtendo um tempo de 1 segundo para processar consultas. Quantos segundos (coloque apenas a quantidade de segundos na resposta) são esperados para 100 milhões de documentos, considerando que o custo é dado pelo número de documentos e que o custo unitário de operação não mudou ?  Lembre que Log(ab) = Log a + Log b. Lembre-se também que (log a)/(log b) dá sempre o mesmo resultado, não importa a base do log. R: 2 segundos
#
# 2. Um estudante faz experimento com uma coleção de 30 mil documentos e testa seu algoritmo de custo O(n), obtendo um tempo de 1 segundo para processar consultas. Quantos segundos (coloque apenas a quantidade de segundos na resposta) são esperados para 30 milhões de documentos, considerando que o custo é dado pelo número de documentos e que o custo unitário de operação não mudou ? R: 1000

# %% [markdown]
# ## Questões de tempo de execução: Resposta
#
# ### Questão 01
# Dados:
# 1. Para um 10 mil documentos demora 1s. Que dá $ 10^4 $ operações.
# 2. Para 100 milhões são $ 10^8 $ operações.
#
# Resolução:
#
# Podemos calcular o fator de crescimento do número de operações como a razão dos logaritmos das duas quantidades:
#
# $$ \frac{\log 10^8}{\log 10^4} = 2 $$
#
# Este fator representa o quanto o número de operações cresceu. Para encontrar o tempo correspondente, multiplicamos esse fator pelo tempo original:
#
# $$ 2 * 1 = 2s $$

# %% [markdown]
# ### Questão 2: Complexidade $O(n^2)$
# Um cientista da computação executa um algoritmo de ordenação com complexidade quadrática em um conjunto de 1000 números e leva 2 segundos. Quantos segundos seriam necessários para ordenar 5000 números, mantendo o mesmo custo unitário de operação?
#
# ### Resolução:
#
# Dados:
# 1. Para um conjunto de 1000 elementos demora 2s. Que dá $ (10^3)^2 = 10^6 $ operações.
# 2. Para 5000 mil são $ (5*10^3)^2 = 5^2 * 10^6 $ operações.
#
# Resolvendo:
#
# $$ \frac{5^2 * 10^6}{10^6} = 5^2 $$
#
# Por fim, temos que o tempo de execução é: $25*2s = 50s$.

# %% [markdown]
# ### Questão 3: Complexidade $O(2^n)$
# Um pesquisador testa um algoritmo recursivo que resolve um problema NP-completo em uma instância de tamanho 10 e leva 1 segundo. Quantos segundos seriam necessários para resolver uma instância de tamanho 20, considerando que o custo cresce exponencialmente com o tamanho da entrada?
#
# ### Resolução:
#
# Dados:
# 1. Para um conjunto de 10 elementos demora 1000s. Que dá $ 2^{10} $ operações.
# 2. Para 20 são $ 2^{20} $ operações.
#
# Resolvendo:
#
# $$ \frac{2^{20}}{2^{10}} = 2^{10} $$
#
# Por fim, temos que o tempo de execução é: $2^{10}*1s = 1024s$.

# %% [markdown]
# ### Questão 4: Complexidade $O(n\log n)$
# Um programador implementa um algoritmo de ordenação eficiente, como o mergesort, em uma lista de 4096 elementos e leva 3 segundos para concluir a ordenação. Quantos segundos seriam necessários para ordenar 8192 elementos, considerando que o custo do algoritmo cresce proporcionalmente a $n\log n$?

# %% [markdown]
# ### Questão 5: Complexidade $O(\sqrt{n})$
# Um analista testa um algoritmo que verifica a primalidade de um número com 10000 elementos e leva 10 segundos para concluir. Quantos segundos seriam necessários para verificar a primalidade de um número com 40000 elementos, considerando que o custo do algoritmo cresce com a raiz quadrada do tamanho da entrada?
#
#
# ### Resolução:
#
# Dados:
# 1. Para um conjunto de 10000 elementos demora 10s. Que dá $ \sqrt{10^{4}} = 10^2 $ operações.
# 2. Para 40000 são $ \sqrt{2^2 * 10^{4}}  = 2 * 10^2 $ operações.
#
# Resolvendo:
#
# $$ \frac{2 * 10^{2}}{10^{2}} = 2 $$
#
# Por fim, temos que o tempo de execução é: $ 2*10s = 20s$.

# %% [markdown]
# ## Questão 01
# 1 - Para cada afirmação abaixo indique se a ela é verdadeira ou falsa. Justifique suas respostas, apenas respostas corretas justificadas corretamente serão consideradas (2 pontos)
#
#
# a) O algoritmo de ordenação conhecido como quicksort foi projetado com a mesma técnica de projeto de algoritmos usada no mergesort.
#
# b) Se $ f(n) $ é $ O(n) $ então é $ f(n) $ também é $ O( n^{1.5} ) $
#
# c) Toda função que é $ 0(n log(n)) $ pode ser descrita como sendo igual a  $ c n log(n) $, onde $ c $ é uma
# constante.
#
# d) Se um programa de custo $ O(n^2) $ é executado em 1 hora para uma entrada de tamanho **x**, sendo **x** muito grande, então ele certamente será executado em tempo de 10 horas para uma entrada de tamanho **10x.**

# %% [markdown]
# ## Reposta questão 01
#
#
#
# **Letra a**: Sim, ambos foram feitos utilizando a ideia de divisão e conquista, que consiste em dividir o problema em partes melhores.
#
# **Letra b**: Sim, o conjunto $ O $ é composto por todas as funções que são maiores ou iguais ao fator, sendo assim, $ f(n) $ por ser $ O(n) $ também pertence a todos os conjuntos iguais ou acima de $ O(n) $, como o $ O(n^{1.5}) $
#
# **Letra c**: Falso, a anotação O big, defini um limite superior de crescimento a uma função, não a forma que a equação deve ter.
#
# **Letra d**: Falso. O programa é um programa quadrático, não linear, logo, o tempo para a execução seria algo perto de $ {10x}^2 $.

# %% [markdown]
# ## Questão 02
#
# 2 - Avalie as seguintes equações de recorrência apresentando a função de custo, sem deixar somatórios e incluindo eventuais constantes. Faça as suposições que forem necessárias para evitar chamadas com valores de n que não sejam inteiros (3,0 pontos)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A)
# $$
# t(n) =
# \begin{cases}
#       0 & \text{if } n =< 0 \\
#       3t(n-1) + 1 & \text{if } n > 0
# \end{cases}
# $$
#
# #### Resolvendo A
#
# Primeiro, usando o metódo da interação.
#
# $$ t(n) = 3t(n-1) + 1 $$
# $$ t(n-1) = 3t(n-2) + 1 $$
# $$ t(n-2) = 3t(n-3) + 1 $$
#
# Fazendo as interações:
#
# $$ t(n) = 3t(n-1) + 1   $$
# $$ t(n) = 3[3t(n-2) + 1] + 1 = 3^2t(n-2) + 3*1 + 1$$
# $$ t(n) = 3^2[3t(n-3) + 1] + 3*1 + 1 = 3^3t(n-3) + 3^2 + 3^1 + 3^0 $$
#
# Seguindo, temos:
# $$ t(n) = 3^3t(n-3) + \sum _{i=0}^{2}\left(3^i\right)$$
#
# Se funciona para 3, funciona para k:
# $$ t(n) = 3^kt(n-k) + \sum _{i=0}^{k-1}\left(3^i\right)$$
#
# Quando terá a para ? Quando $n-k = 0$, sendo assim, $k = n$
# $$ t(n) = 3^nt(n-n) + \sum _{i=0}^{n-1}\left(3^i\right)$$
#
# Sabe-se que $t(0)$ é $0$, logo, $3^nt(n-n)$ é $0$.
# Portanto, temos:
# $$\sum _{i=0}^{n-1}\left(3^i\right)$$
#
# Para esse somatório, a formula é a seguinte:
# $$\sum _{i=0}^{n}\left(a^i\right) = \frac{a^{n+1} - 1}{a - 1}$$
#
# Substituindo os valores na formula:
# $$\sum _{i=0}^{n-1}\left(3^i\right) = \frac{3^{n} - 1}{ 3- 1} = \frac{3^{n} - 1}{ 2 }$$
#
# Agora, precisamos saber qual a classe de complexidade que essa função pertence, para isso vou calcular o limite.
#
# $$\lim _{n\to \infty }\left(\frac{\left(\frac{3^n\:-\:1}{\:2\:}\right)}{3^n}\right)$$
#
# $$\lim _{n\to \infty }\left(\frac{3^n-1}{2*3^n}\right)$$
#
# Dividindo o númerador e denominador por $3^n$.
#
#
# $$\lim _{n\to \infty }\left(\frac{1-\frac{1}{3^n}}{2}\right)$$
#
# Sendo assim, tem-se que o limite é $ \frac{1}{2}$.
#
#
# Portanto, temos que o algoritmo é $\Theta(3^n)$, isso porque o limite é uma costante não nula.

# %% [markdown]
# B)
# $$
# t(n) =
# \begin{cases}
#       1 & \text{if } n = 1 \\
#       8t(\frac{n}{2}) + c & \text{if } n > 1
# \end{cases}
# $$
#
# #### Resolvendo B
#
# Usando o teorema mestre:
# $a = 8$
# $b = 2$
# $ f(n) = c$
# $$ n^{\log _2\left(8\right)} = n^3 $$
#
# Como a segunda parte da equação é uma constante, então termos o primeiro caso do teorema mestre, em que:
# $$
# f(n) = O(n^{\log _b\left(a\right)-e})
# $$
# Logo, sabe-se que a equação é $ \Theta(n^3)$.
#
# Usando o metódo da interação:
#
# $$ t(n) = 8t(\frac{n}{2}) + c $$
# $$ t(\frac{n}{2}) = 8t(\frac{n}{2^2}) + c $$
# $$ t(\frac{n}{2^2}) = 8t(\frac{n}{2^3}) + c $$
#
# Expandindo a equação:
# $$ t(n) = 8[8t(\frac{n}{2^2}) + c ] + c = 8^2t(\frac{n}{2^2}) + 8c + c$$
# $$ t(n) = 8^2[8t(\frac{n}{2^3}) + c] + 8c + c = 8^3t(\frac{n}{2^3}) + 8^2c + 8^1c + 8^0c$$
#
# Para 3 interações temos:
#
# $$ t(n) = 8^3t(\frac{n}{2^3}) + 8^2c + 8^1c + 8^0c$$
#
# $$ t(n) = 8^3t(\frac{n}{2^3}) + c\sum _{i=0}^{2}\left( 8^i \right)$$
# $$ … …$$
# $$ t(n) = 8^kt(\frac{n}{2^k}) + c\sum _{i=0}^{k-1} \left(8^i\right) $$
#
# Quando para? Quando $ \frac{n}{2^k} = 1$, logo temos que: $ k = \log _2 \left(n\right)$
#
# Assim temos:
# $$ t(n) = 8^{\log _2 \left(n\right)} + c\sum _{i=0}^{\log _2 \left(n\right)-1} \left(8^i\right) $$
#
# Sabe-se que, $8^{\log _2 \left(n\right)} = 2^{3\log _2 \left(n\right)} = n^3$
#
# Portanto, temos:
# $$ t(n) = n^3 + c\sum _{i=0}^{\log _2 \left(n\right)-1} \left(8^i\right) $$
#
# Calculando o somatório, tem-se:
# $$
# \sum _{i=0}^{\log _2 \left(n\right)-1} \left(8^i\right) = \frac{8^{\log _2 \left(n\right)} -1 }{8-1} = \frac{n^3 -1}{7}
# $$
#
# Substituindo na formula original;
# $$
# t(n) = n^3 + c\left(\frac{n^3 -1}{7}\right)
# $$

# %% [markdown]
# C)
# $$
# t(n) =
# \begin{cases}
#       n & \text{if } n = 1, n = 0 \\
#       2t(n-1) + 3t(n-2) & \text{if } n > 1
# \end{cases}
# $$
#
# #### Resolvendo C
#
# Para essa questão vou usar o polinômio aniquilador.
#
# $$ t(n) = 2t(n-1) + 3t(n-2)$$
# $$ t(n) - 2t(n-1) - 3t(n-2)= 0$$
#
# Assim, temos o polinômio:
# $$ E^2 - 2E - 3$$
#
# Agora procurando as raizes:
#
# $$ \frac{-b \pm \sqrt(b^2 - 4.a.c)}{2.a} $$
#
# $$ \frac{2 \pm \sqrt(4 - 4.1.(-3))}{2.1} $$
# $$ \frac{2 \pm \sqrt(4 + 12 )}{2} $$
# $$ \frac{2 \pm \sqrt( 16 )}{2} $$
# $$ \frac{2 \pm 4}{2} $$
#
# Por fim, temos que as duas raizes são:
#
# $$ r1 = 3$$
# $$ r2 = -1$$
#
# Para encontrar a fórmula dessa questão, tem a equação:
#
# 1. Para quando as raizes são iguais: $ t(n) =  c1.r1^n + c2.n.r2^n$
# 2. Para raizes distintas: $ t(n) = c1.r1^n + c2.r2^n$

# %% [markdown]
# ## Questão 03
#
# 3 - Utilize o teorema mestre para indicar a complexidade das seguintes equações de recorrência:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A)
# $$
# t(n) =
# \begin{cases}
#       1 & \text{if } n = 1 \\
#       8t(\frac{n}{2}) + n & \text{if } n > 1
# \end{cases}
# $$
#
# ### Resolvendo questão A - Teorema Mestre:
#
# A formula do teorema mestre é: $ n^{\log_{b}{a} - ϵ} $
#
# Assim:
# $$ a=8 $$
# $$ b=2 $$
# $$ f(n) = n$$
#
# Logo,
# $$ \log_{2}{8} = 3 $$
#
# Isso implica em: $ n^3 $
#
# Caindo assim no primeiro caso do teorema mestre, logo isso é $Θ(n^3)$.

# %% [markdown]
# B)
# $$
# t(n) =
# \begin{cases}
#       1 & \text{if } n = 1 \\
#       2t(\frac{n}{2}) + \log{n} & \text{if } n > 1
# \end{cases}
# $$
#
# C)
# $$
# t(n) =
# \begin{cases}
#       1 & \text{if } n = 1 \\
#       4t(\frac{n}{2}) + n^2 & \text{if } n > 1
# \end{cases}
# $$

# %% [markdown]
# ## Código para equação

# %% [markdown]
# ## Bubble Sort
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Codigo em C

# %%
# @title
code = """
#include <stdio.h>

int bubbleSort(int* A, int n){

  for(int i=n-1; i > 0; i--){

    for(int j=0; j < i; j++){

      if(A[j] < A[j+1]){
        int tmp = A[j];
        A[j] = A[j+1];
        A[j+1] = tmp;
      }

    }

  }

}

void printVector(int* A, int n){

    printf("{ ");
    for(int i=0; i < n; i++){
      printf("%d, ", A[i]);
    }
    printf(" }\\n");
}

int main(){
  int arr[] = {6, 3, 0, 5};

  printVector(arr,4);
  bubbleSort(arr,4);
  printVector(arr,4);

}

"""

with open("bubble.c", "w") as f:
  f.write(code)

# %%
# !gcc bubble.c -o bubble.out
# !./bubble.out
# Out:
# KK: { 6, 3, 0, 5,  }
# KK: { 6, 5, 3, 0,  }

# %% [markdown]
# ### Tentando resolver
#
# ```c
#   int bubbleSort(int* A, int n){
#
#     for(int i=n-1; i > 0; i--){
#
#       for(int j=0; j < i; j++){
#
#         if(A[j] < A[j+1]){
#
#           int tmp = A[j];
#           A[j] = A[j+1];
#           A[j+1] = tmp;
#
#         }
#
#       }
#     }
#   }
#
# ```
# 1. Para a função mais externa temos:$\sum _{i=1}^{n-1}\left(1\right)$
# 2. Para a função interna temos: $\sum _{i=0}^{n-i-1}\left(1\right)$
#
# ### Calculando o mais interno temos:
#
# $$
# \sum _{i=a}^{n}\left(1\right) = (n-a)+1
# $$
#
# logo,
# $$
# \sum _{j=0}^{n-i-1}\left(1\right) = (n-i-1-0)+1 = n-i
# $$
# Agora revendo o somatorio mais interno temos:
#
# $$
# \sum _{i=1}^{n-1}\left(n-i\right)
# $$
#
# Isso é o mesmo que:
#
# $$
# \sum _{i=1}^{n-1}\left(n\right) - \sum _{i=1}^{n-1}\left(i\right)
# $$
#
# Que é o mesmo que:
# $$
# n*\sum _{i=1}^{n-1}\left(1\right) - \sum _{i=1}^{n-1}\left(i\right)
# $$
#
# Calculando $n*\sum _{i=1}^{n-1}\left(1\right)$ temos:
# $$
# n*[(n-1-1)+1] = n*[(n-2)+1] = n*n-1
# $$
# Por fim, essa parte resulta em: $ n^2 - n $
#
# Agora Calculando a segunda parte da equanção temos:
# $$
# \sum _{i=1}^{n}\left(i\right) = \frac{n(n+1)}{2}
# $$
#
# Logo,
# $$
# \sum _{i=1}^{n-1}\left(i\right) = \frac{n-1(n-1+1)}{2} = \frac{n-1(n)}{2} = \frac{n^2-n}{2}
# $$
#
# Juntando os dois somatórios temos:
# $$
#  n^2 - n -\frac{n^2-n}{2} = \frac{2n^2 - 2n - n^2 - n}{2} = \frac{n^2-3
#  n}{2}
# $$
#
# Portanto a equação fechado do bubble sort é $ \frac{n^2-3
#  n}{2} $

# %% [markdown]
# ### Insertion Sort
#
# ```plaintext
# procedimento insertionSort(A: lista de itens)
#    N <- tamanho de A
#    para i de 1 até N-1 faça
#        chave <- A[i]
#        j <- i - 1
#        enquanto j >= 0 e A[j] > chave faça
#            A[j+1] <- A[j]
#            j <- j - 1
#        fim enquanto
#        A[j+1] <- chave
#    fim para
# fim procedimento

# %% [markdown]
# ### Codigo em C

# %%
# @title
code = """
#include <stdio.h>

int insertionSort(int* A, int n){

  int pivo;
  int i;
  for(i=1; i < n; i++){

    pivo = A[i];

    int j = 0;
    while (j < i && A[i-1-j] > pivo)
    {
        A[i-j] = A[i-1-j];
        j++;
    }

    A[i-j] = pivo;


  }

}


void printVector(int* A, int n){

    printf("{ ");
    for(int i=0; i < n; i++){
      printf("%d, ", A[i]);
    }
    printf(" }\\n");
}

int main(){
  int arr[] = {6, 3, 0, 5};

  printVector(arr,4);
  insertionSort(arr,4);
  printVector(arr,4);

}

"""

with open("insertion_sort.c", "w") as f:
  f.write(code)

# %%
# @title
# !gcc insertion_sort.c -o insertion_sort.out
# !./insertion_sort.out
# Out:
# { 6, 3, 0, 5,  }
# { 0, 3, 5, 6,  }

# %% [markdown]
# ### Tentando Resolver
#
# ```c
# int insertionSort(int* A, int n){
#
#   int pivo;
#   int i;
#   for(i=1; i < n; i++){
#
#     pivo = A[i];
#
#     int j = 0;
#     while (j < i && A[i-1-j] > pivo)
#     {
#         A[i-j] = A[i-1-j];
#         j++;
#     }
#
#     A[i-j] = pivo;
#
#   }
#
# }
#
# ```
#
# 1. Para a função mais externa temos:$\sum _{i=1}^{n-1}\left(1\right)$
# 2. Para a função interna temos: $\sum _{j=0}^{i-1}\left(1\right)$
#
# Resultando em:
# $$
# \sum _{i=1}^{n-1}\left(\sum _{j=0}^{i-1}\left(1\right)\right)
# $$
#
# Para calcular o somatório interno, usamos a fórmula:
# $$
# \sum _{i=a}^{n}\left(1\right) = (n-a)+1
# $$
# Logo,
# $$
# \sum _{j=0}^{i-1}\left(1\right) = (i-1-0)+1 = (i)
# $$
#
# Segue,
# $$
# \sum _{i=1}^{n-1}\left(i\right)
# $$
#
# Para esse somatório temos a fórmula:
# $$
# \sum _{i=1}^{n}\left(i\right) = \frac{n(n+1)}{2}
# $$
#
# Sendo assim,
# $$
# \sum _{i=1}^{n-1}\left(i\right) = \frac{n-1(n)}{2} = \frac{n^2-n}{2}
# $$
#
# Portanto a equação da complexidade do insert sort fechada é: $$\frac{n^2-n}{2}$$

# %% [markdown]
# ## Selection Sort
#
# ```plaintext
# procedimento selectionSort(A: lista de itens)
#    N <- tamanho de A
#    para i de 0 até N-2 faça
#        minIndex <- i
#        para j de i+1 até N-1 faça
#            se A[j] < A[minIndex] então
#                minIndex <- j
#            fim se
#        fim para
#        se minIndex != i então
#            trocar A[i] e A[minIndex]
#        fim se
#    fim para
# fim procedimento
# ```

# %% [markdown]
# ### Codigo em C

# %%
# @title
code = """
#include <stdio.h>

int selectionSort(int* A, int n){


  for(int i=0; i < n-1;i++){

    int i_bigger = i;

    for(int j=i+1; j < n;j++){
      if(A[j] < A[i_bigger]) i_bigger = j;

    }

    int aux = A[i_bigger];
    A[i_bigger] = A[i];
    A[i] = aux;

  }

}


void printVector(int* A, int n){

    printf("{ ");
    for(int i=0; i < n; i++){
      printf("%d, ", A[i]);
    }
    printf(" }\\n");
}

int main(){
  int arr[] = {6, 3, 0, 5};

  printVector(arr,4);
  selectionSort(arr,4);
  printVector(arr,4);

}

"""

with open("selection_sort.c", "w") as f:
  f.write(code)

# %%
# @title
# !gcc selection_sort.c -o selection_sort.out
# !./selection_sort.out
# Out:
# { 6, 3, 0, 5,  }
# { 0, 3, 5, 6,  }

# %% [markdown]
# ### Tentando Resolver
# ```c
# int selectionSort(int* A, int n){
#
#   for(int i=0; i < n-1;i++){
#
#     int i_bigger = i;
#
#     for(int j=i+1; j < n;j++)
#       if(A[j] < A[i_bigger]) i_bigger = j;
#
#     int aux = A[i_bigger];
#     A[i_bigger] = A[i];
#     A[i] = aux;
#
#   }
#
# }
# ```
#
# 1. O for externo temos: $\sum _{i=0}^{n-2}$
# 2. Laço

# %% [markdown]
# ## Heap Sort
#
# ```
# procedimento heapSort(A: lista de itens)
#    N <- tamanho de A
#
#    // Construir um heap máximo
#    para i de N/2 - 1 até 0 faça
#        heapify(A, N, i)
#    fim para
#
#    // Extrair elementos do heap um por um
#    para i de N-1 até 0 faça
#        // Trocar o elemento atual com o último elemento
#        trocar A[0] e A[i]
#
#        // Chamar heapify no heap reduzido
#        heapify(A, i, 0)
#    fim para
# fim procedimento
#
# procedimento heapify(A: lista de itens, N: int, i: int)
#    maior <- i
#    l <- 2*i + 1
#    r <- 2*i + 2
#
#    // Se o filho esquerdo for maior que a raiz
#    se l < N e A[l] > A[maior] então
#        maior <- l
#    fim se
#
#    // Se o filho direito for maior que o maior até agora
#    se r < N e A[r] > A[maior] então
#        maior <- r
#    fim se
#
#    // Se o maior não for a raiz
#    se maior != i então
#        trocar A[i] e A[maior]
#
#        // Chamar heapify recursivamente no subárvore afetado
#        heapify(A, N, maior)
#    fim se
# fim procedimento
#
# ```

# %% [markdown]
# ## Função Recursiva
#
# ```
# função recursiva(n: int)
#    se n = 0 então
#        retornar 1
#    fim se
#    retornar recursiva(n-1) + recursiva(n-1) + recursiva(n-1)
# fim função
#
# ```

# %% [markdown]
# ##  Soma de Elementos de uma Lista
#
# ```
# função soma(A: lista de itens)
#    total <- 0
#    N <- tamanho de A
#    para i de 0 até N-1 faça
#        total <- total + A[i]
#    fim para
#    retornar total
# fim função
#
# ```

# %% [markdown]
# ## Verificar se um Número é Primo
#
# ```
# função éPrimo(n: int)
#    se n <= 1 então
#        retornar falso
#    fim se
#    para i de 2 até sqrt(n) faça
#        se n mod i = 0 então
#            retornar falso
#        fim se
#    fim para
#    retornar verdadeiro
# fim função
#
# ```

# %% [markdown]
# ## Função Recursiva 2
#
# ```
#
# função exponencial(n: int)
#    se n = 0 então
#        retornar 1
#    fim se
#    retornar exponencial(n-1) + exponencial(n-1) + exponencial(n-1) + exponencial(n-1) + exponencial(n-1)
# fim função
#
#
# ```

# %% [markdown]
# ## Função Recursiva 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
# função exponencial(n: int)
#
#    se n > 0 então
#        de i<-0->n-1 faça
#           exponencial(n-1)
#           i<-i+1
#    fim se
#
#
# fim função
#
#
# ```

# %%
def cal(n):
  return n*cal(n-1) if n > 0 else 1

cal(4)
# Out:
# 24

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Isso é $ O(n^n) $
# $$ t(n) = n*t(n-1) + c $$
# $$ t(n-1) = n-1 * t(n-2) +c $$
# $$ t(n-2) = n-2 * t(n-3) + c $$
#
# Junto na equação:
#
# $$
# t(n) = n* [ n-1 * t(n-2) +c] + c = (n^2-n)*t(n-2) + nc + c
# $$
#
# $$
# t(n) = (n^2-n)* [n-2 * t(n-3) + c] + nc + c
# $$
#
# $$
# t(n) = n^3-3n^2+2n*t(n-3) + n^2c + c
# $$

# %% [markdown]
# ## Exercício Formulario Classrom

# %% [markdown]
# $$
# t(n) =
# \begin{cases}
#       1 & \text{if } n = 1 \\
#       t(\frac{n}{8}) + \log(n) & \text{if } n > 1
# \end{cases}
# $$
#
# ### Resolvendo
#
# Calculando os casos:
#
# $$ t(n) = t(\frac{n}{8}) + \log(n)$$
# $$ t(\frac{n}{8}) = t(\frac{n}{8^2}) + \log(\frac{n}{8})$$
# $$ t(\frac{n}{8^2}) = t(\frac{n}{8^3}) + \log(\frac{n}{8^2})$$
#
# Juntando os valores:
# $$ t(n) = t(\frac{n}{8}) + \log(n)$$
# $$ t(n) = t(\frac{n}{8^2}) + \log(\frac{n}{8}) + \log(n)$$
# $$ t(n) =  t(\frac{n}{8^3}) + \log(\frac{n}{8^2}) + \log(\frac{n}{8^1}) + \log(\frac{n}{8^0})$$
#
# Se funciona para 3, funciona para k:
#
# $$ t(n) =  t(\frac{n}{8^k}) + \sum _{i=0}^{k-1} \log(\frac{n}{8^i})$$
#
#
# Para quando ? $\frac{n}{8^{k}} = 1$ temos que $k = \log _{8}{n} $
#
# Temos, então:
# $$ t(n) =  t(\frac{n}{2^{\log _{8}{n}}}) + \sum _{i=0}^{\log _{8}{n}-1} \log(\frac{n}{8^{i}})$$
#
# $$ t(n) =  1 + \sum _{i=0}^{\log _{8}{n}-1} \log(\frac{n}{8^{i}})$$
#
# Usando as propriedades do log:
# $$ t(n) =  1 +\sum _{i=0}^{\log _{8}{n}-1} \log(n) - \sum _{i=0}^{\log _{8}{n}-1} \log(8^{i})$$
#
# Calculando o primeiro somatório:
# $$\sum _{i=0}^{\log _{8}{n}-1} \log(n)$$
# $$\log(n)*\sum _{i=0}^{\log _{8}{n}-1} 1$$
# $$\log(n)*\log _{8}{n}$$
#
# Calculando o segundo somatorio, supondo que a base do log é 2. 😀 :
#
# $$\sum _{i=0}^{\log _{8}{n}-1} \log(2^{3i})$$
#
# $$\sum _{i=0}^{\log _{8}{n}-1} 3i$$
#
# $$ 3*\sum _{i=0}^{\log _{8}{n}-1} i $$
#
# Para esse tipo de somatório temos a fórmula:
# $$\sum _{i=1}^{n} i = \frac{n(n+1)}{2}$$
#
# Logo, usando a formula, temos:
# $$ \frac{3}{2}* (\log _{8}{n}*(\log _{8}{n}-1)) $$
#
#
# Juntando tudo:
# $$ t(n) =  1 + \log(n)*\log _{8}{n} - [  \frac{3}{2}* (\log _{8}{n}*(\log _{8}{n}-1))]$$

# %% [markdown]
# # Programação dinâmica
#
# Dividir o problema em subproblemas menores, calculando cada subproblema uma única vez. Assim, eliminando as redundâncias.
